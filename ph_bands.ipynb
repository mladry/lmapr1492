# %%
import numpy as np
import matplotlib.pyplot as plt
from pymatgen.ext.matproj import MPRester
from pymatgen import Structure
from jupyter_jsmol.pymatgen import quick_view
from pymatgen.phonon import plotter
from pymatgen.phonon.plotter import PhononBSPlotter
from pymatgen.phonon.bandstructure import PhononBandStructure

import numpy as np
import matplotlib.pyplot as plt
from pymatgen.ext.matproj import MPRester
from pymatgen import Structure
from jupyter_jsmol.pymatgen import quick_view
from pymatgen.phonon import plotter
from pymatgen.phonon.plotter import PhononBSPlotter
from pymatgen.phonon.bandstructure import PhononBandStructure

# %%
with MPRester('brNMq9mRKCbXNGk2k') as m:
    bandstucture = m.get_phonon_bandstructure_by_material_id('mp-2074') 
phonon_plot = PhononBSPlotter(bandstucture)

# %%
phonon_plot.get_plot()
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib64/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
phonon_plot.plot_brillouin()

# %%
phonon_plot.get_plot()
plt.title('Réprésentation des 3 premières branches acoustiques qui vont être analysées')
for i in range(len(bs_plot_data_phonon.get('distances'))):
    plt.plot(bs_plot_data_phonon.get('distances')[i],bs_plot_data_phonon.get('frequency')[i][0],'green')  #On trace la première branche acoustique
    plt.plot(bs_plot_data_phonon.get('distances')[i],bs_plot_data_phonon.get('frequency')[i][1],'red')    #On trace la deuxième branche acoustique
    plt.plot(bs_plot_data_phonon.get('distances')[i],bs_plot_data_phonon.get('frequency')[i][2],'orange') #On trace la troisième branche acoustique

# %%
ang = 10**(-10)
distances = bs_plot_data_phonon.get("distances")
frequences = bs_plot_data_phonon.get("frequency")

# %%
print('Première direction: Γ−X')

v1 = (2*np.pi*((frequences[0][0][1] - frequences[0][0][0])*10**12))/((distances[0][1] - distances[0][0])/ang)
v2 = (2*np.pi*((frequences[0][1][1] - frequences[0][1][0])*10**12))/((distances[0][1] - distances[0][0])/ang)
v3 = (2*np.pi*((frequences[0][2][1] - frequences[0][2][0])*10**12))/((distances[0][1] - distances[0][0])/ang)
print('vitesse du son de la courbe verte', v1)
print('vitesse du son de la courbe rouge', v2)
print('vitesse du son de la courbe jaune', v3)
# Out:
# Première direction: Γ−X
# vitesse du son de la courbe verte 3744.562691931182
# vitesse du son de la courbe rouge 3773.4784768914037
# vitesse du son de la courbe jaune 3773.478476891527

# %%
print('Deuxième direction: Γ−K')

v1 = (2*np.pi*((frequences[3][0][-1] - frequences[3][0][-2])*10**12))/((distances[3][-1] - distances[3][-2])/ang)
v2 = (2*np.pi*((frequences[3][1][-1] - frequences[3][1][-2])*10**12))/((distances[3][-1] - distances[3][-2])/ang)
v3 = (2*np.pi*((frequences[3][2][-1] - frequences[3][2][-2])*10**12))/((distances[3][-1] - distances[3][-2])/ang)
print('vitesse du son de la courbe verte', v1)
print('vitesse du son de la courbe rouge', v2)
print('vitesse du son de la courbe jaune', v3)
# Out:
# Deuxième direction: Γ−K
# vitesse du son de la courbe verte -1779.054681327003
# vitesse du son de la courbe rouge -3776.6516092369206
# vitesse du son de la courbe jaune -5004.231605132474

# %%
print('Deuxième direction: Γ−L')

v1 = (2*np.pi*((frequences[4][0][1] - frequences[4][0][0])*10**12))/((distances[4][1] - distances[4][0])/ang)
v2 = (2*np.pi*((frequences[4][1][1] - frequences[4][1][0])*10**12))/((distances[4][1] - distances[4][0])/ang)
v3 = (2*np.pi*((frequences[4][2][1] - frequences[4][2][0])*10**12))/((distances[4][1] - distances[4][0])/ang)
print('vitesse du son de la courbe verte', v1)
print('vitesse du son de la courbe rouge', v2)
print('vitesse du son de la courbe jaune', v3)
# Out:
# Deuxième direction: Γ−L
# vitesse du son de la courbe verte 2618.746148275156
# vitesse du son de la courbe rouge 2618.746148276203
# vitesse du son de la courbe jaune 5364.426709300643
