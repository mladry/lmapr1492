# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.analysis.diffraction.xrd import XRDCalculator
from pymatgen.analysis.diffraction.core import AbstractDiffractionPatternCalculator
with MPRester ("brNMq9mRKCbXNGk2k") as mp:
    structure = mp.get_structure_by_material_id("mp-2074")

# %%
lam = 1.5406
xrd = XRDCalculator(wavelength=lam)
pat = xrd.get_pattern(structure)
print(pat)
# Out:
# DiffractionPattern
# $2\Theta$: [23.46346433 27.15787382 38.78477711 45.82768799 47.99028301 56.01271996
#  61.55447481 63.33577812 70.21368038 75.17738105 83.22228908 87.97521353
#  89.55481374]
# Intensity: [100.          52.09762811  55.60495115  49.57564495  14.39841127
#    9.38650671  20.15406218  18.47232935  18.81103972  14.96444057
#    5.92378657  15.53997443   9.40311075]

# %%
plot = xrd.get_plot(structure,two_theta_range=(0, 40))

# %%
print('pic 1')
print(' Theta 1 = 23.46346433 \n I1 = 100. ')
print(str(pat.hkls[0]))


print('pic 2')
print(' Theta 2 = 27.15787382 \n I2 = 52.09762811 ')
print(str(pat.hkls[1]))


print('pic 3')
print('Theta 3 = 38.78477711 \n I3 = 55.60495115 ')
print(str(pat.hkls[2]))
# Out:
# pic 1
#  Theta 1 = 23.46346433
#  I1 = 100.
# [{'hkl': (1, 1, 1), 'multiplicity': 2}, {'hkl': (1, 0, 0), 'multiplicity': 6}]
# pic 2
#  Theta 2 = 27.15787382
#  I2 = 52.09762811
# [{'hkl': (1, 1, 0), 'multiplicity': 6}]
# pic 3
# Theta 3 = 38.78477711
#  I3 = 55.60495115
# [{'hkl': (2, 1, 1), 'multiplicity': 6}, {'hkl': (1, 0, -1), 'multiplicity': 6}]
